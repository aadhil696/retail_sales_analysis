# %% [markdown]
# ## Project Overview- Retail Sales Analysis
# ##### This project focuses on analyzing a Retail Sales dataset of records to uncover meaningful business insights.The primary objective is to apply Python (Pandas) for data cleaning, transformation, and exploration, combined with Oracle SQL for advanced querying and trend analysis.
#
# ### 🎯 Project Goals
# ##### -Determine best-selling products across different regions.
# ##### -Analyze month-over-month growth trends for sales.
# ##### -Explore category-level sales patterns.
# ##### -Evaluate sub-category profitability improvements to know areas of business growth.

# %% [markdown]
# ### Kaggle Installation

# %%
#!pip install kaggle
# !pip install --upgrade kaggle urllib3

# %% [markdown]
# ### Data Import

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# retail-orders.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('retail-orders.zip')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
data = pd.read_csv('orders.csv')
data.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %% [markdown]
# ### Data Cleaning

# %%
#Check unique values in the column to see the presence of different null values
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
#Change different unknown values as null valuess
data = pd.read_csv('orders.csv',na_values=['Not Available', 'unknown'])
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#Standardize columns by lower casing first letter and replace space with '_'
data.columns = data.columns.str.lower()
data.columns = data.columns.str.replace(' ','_')
data.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#check the data types and convert it if necessary
data.dtypes
# Out:
# order_id             int64
# order_date          object
# ship_mode           object
# segment             object
# country             object
# city                object
# state               object
# postal_code          int64
# region              object
# category            object
# sub_category        object
# product_id          object
# cost_price           int64
# list_price           int64
# quantity             int64
# discount_percent     int64
# dtype: object

# %%
#change order_date dtype from object to date
data['order_date'] = pd.to_datetime(data['order_date'], format = "%Y-%m-%d")
data.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# dtype: object

# %% [markdown]
# ### Feature Engineering - Creating Business Metrics

# %%
#find discount amount with list price and discount percentage
data['discount'] = data['list_price'] * data['discount_percent'] * .01
data.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#find sale price with list price and discount amount
data['sale_price'] = data['list_price'] - data['discount']
data.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#find the profit
data['profit'] = data['sale_price'] - data['cost_price']
data.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#remove unnecessary columns
data.drop(columns = ['list_price', 'cost_price', 'discount_percent'], inplace = True)
data.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %% [markdown]
# ### Oracle Database Setup & Data Integration

# %%
#install oracle db
# !pip install oracledb

# %%
import sqlalchemy as sa

#Oracle details
username = "system"
password = "123123"
host = "192.168.1.8"
port = "1521"
service_name = "XE"

#Create connection string
dsn = sa.engine.URL.create(
    "oracle+oracledb",
    username=username,
    password=password,
    host=host,
    port=port,
    database=service_name
)

engine = sa.create_engine(dsn)

#Test connection
with engine.connect() as conn:
    print("COnnected:", conn)
# Out:
# COnnected: <sqlalchemy.engine.base.Connection object at 0x000001F3F1A07460>

# %%
from sqlalchemy import Numeric
dtype_mapping = {col: Numeric() for col in data.select_dtypes("float").columns} #to overcome oracle float-binary error
data.to_sql('df_orders',con = engine, index = False, if_exists = 'replace', dtype=dtype_mapping)
# Out:
# -1

# %% [markdown]
# ### Future Enhancements
# #### 1.Interactive Dashboards
# ##### --Develop interactive dashboards in Power BI to visualize sales trends, category-level performance, and key KPIs for better decision-making.
#
#
# #### 2.Predictive Analyticys
#
# ##### --Apply time series forecasting (e.g., ARIMA, Prophet) to predict sales trends.
#
# ##### --Use machine learning models to predict customer demand or profitability.
